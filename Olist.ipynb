# %% [markdown]
# Case Study: Diagnosing and Advising an E-commerce Company

# %%
# 2-2 Data Import

import pandas as pd # Python library for data wrangling and basic analysis

# importing the data as dataframe objects
customers = pd.read_csv("/Users/Jun/Desktop/Olist/olist_customers_dataset.csv")
order_items = pd.read_csv("/Users/Jun/Desktop/Olist/olist_order_items_dataset.csv")
order_reviews = pd.read_csv("/Users/Jun/Desktop/Olist/olist_order_reviews_dataset.csv")
orders = pd.read_csv("/Users/Jun/Desktop/Olist/olist_orders_dataset.csv")
products = pd.read_csv("/Users/Jun/Desktop/Olist/olist_products_dataset.csv")
sellers = pd.read_csv("/Users/Jun/Desktop/Olist/olist_sellers_dataset.csv")
categories = pd.read_csv("/Users/Jun/Desktop/Olist/product_category_name_translation.csv")

# %%
# 2-3 Checking for ROSCC

# enabling display of every output from one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# checing for reliability (accuracy)
customers.head(3) # no need to check for anything

order_items.head(3)
order_items.describe() # both price & freight_value are made up of reasonable values only

order_reviews.head(3)

# every review_answer_timestamp comes after review_creation_date
sum(order_reviews["review_creation_date"] > order_reviews["review_answer_timestamp"])
orders.head(3)
sum(orders["order_purchase_timestamp"] > orders["order_approved_at"]) # no issue found

# issue found - over 1000 orders approved after being delivered to carrier
sum(orders["order_approved_at"] > orders["order_delivered_carrier_date"])

# issue found likewise
sum(orders["order_delivered_carrier_date"] > orders["order_delivered_customer_date"])
sum(orders["order_purchase_timestamp"] > orders["order_delivered_customer_date"]) # no issue found

products.head(3)
products.describe() # all figures valid; no issue found

sellers.head(3) # no need

categories.head(3) # no need

# checing for sufficiency (completeness)
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(customers.isnull(), cbar = False) # no missing values
plt.show()
sns.heatmap(order_items.isnull(), cbar = False) # no missing values
plt.show()
sns.heatmap(order_reviews.isnull(), cbar = False) # extent of missing values unproblematic
plt.show()
sns.heatmap(orders.isnull(), cbar = False) # extent of missing values unproblematic
plt.show()
sns.heatmap(products.isnull(), cbar = False) # extent of missing values unproblematic
plt.show()
sns.heatmap(sellers.isnull(), cbar = False) # no missing values
plt.show()
sns.heatmap(categories.isnull(), cbar = False) # no missing values
plt.show()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24
# 0
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 0
# 1359
# 23
# 0
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto

# %%
# 3-1 Merging

# join 1
# creating 'order_items_new'
order_items_new = order_items.groupby(["order_id", "product_id"]).agg({"order_item_id": "count", "seller_id": "max", "price": "sum", "freight_value": "sum"}).reset_index()
order_items_new.columns = ["order_id", "product_id", "quantity", "seller_id", "price", "freight_value"]
order_items_new.head(10) # granularity: every product from every order

orders_new = pd.merge(left = orders, right = order_items_new, how = "left", on = "order_id")
orders_new.head(5) # granularity: every product from every order (no order dropped)

# join 2
orders_new = pd.merge(left = orders_new, right = products, how = "left", on = "product_id")
orders_new.head(5) # granularity: every product from every order (no order dropped)

# join 3
orders_new = pd.merge(left = orders_new, right = categories, how = "left", on = "product_category_name")
orders_new.head(5) # granularity: every product from every order (no order dropped)

# join 4
orders_new = pd.merge(left = orders_new, right = sellers, how = "left", on = "seller_id")
orders_new.head(5) # granularity: every product from every order (no order dropped)

# join 5
orders_new = pd.merge(left = orders_new, right = customers, how = "left", on = "customer_id")
orders_new.head(5) # granularity: every product from every order (no order dropped)

# join 6
# creating 'order_reviews_new'
temp = orders_new.groupby("order_id")["product_id"].count()
single_product_orders = pd.DataFrame(temp[temp == 1].index) # orders that have only one product
single_product_orders["is_single_product_order"] = True
order_reviews_new = pd.merge(left = single_product_orders, right = order_reviews, how = "right", on = "order_id")
order_reviews_new["product_review_score"] = order_reviews_new["review_score"]

import numpy as np
order_reviews_new.loc[order_reviews_new["is_single_product_order"] != True, "product_review_score"] = np.nan
order_reviews_new = order_reviews_new[["order_id", "review_score", "product_review_score"]]
order_reviews_new.rename(columns = {"order_id":"order_id", "review_score":"overall_order_review_score", "product_review_score":"overall_product_review_score"}, inplace = True)
order_reviews_new = order_reviews_new.groupby("order_id")["overall_order_review_score","overall_product_review_score"].agg("mean").reset_index() # granularity: every aggregated review from every order

orders_new = pd.merge(left = orders_new, right = order_reviews_new, how = "left", on = "order_id")
orders_new.head(5) # granularity: every product from every order (no order dropped)

orders_new.drop_duplicates(inplace = True) # ensuring no perfect duplicates
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# 5  00048cc3ae777c65dbb7d2a0634bc1ea  ef92defde845ab8450f9d70c526ef70f
# 6  00054e8431b9d7675808bcb819fb4a32  8d4f2bb7e93e6710a28f34fa83ee7d28
# 7  000576fe39319847cbb9d288c5617fa6  557d850972a7d6f792fd18ae1400d9b6
# 8  0005a1a1728c9d785b8e2b08b904576c  310ae3c140ff94b03219ad0adc3c778f
# 9  0005f50442cb953dcd1d21e1fb923495  4535b0e1091c278dfd193e5a1d63b39f
#
#    quantity                         seller_id   price  freight_value
# 0         1  48436dade18ac8b2bce089ec2a041202   58.90          13.29
# 1         1  dd7ddc04e1b6c2c614352b383efe2d36  239.90          19.93
# 2         1  5b51032eddd242adc84c38acab88f23d  199.00          17.87
# 3         1  9d7a1d34a5052409006425275ba1c2b4   12.99          12.79
# 4         1  df560393f3a51e74553ab94004ba5c87  199.90          18.14
# 5         1  6426d21aca402a131fc0a5d0960a3c90   21.90          12.69
# 6         1  7040e82f899a04d1b434b795a43b4617   19.90          11.85
# 7         1  5996cddab893a4652a15592fb58ab8db  810.00          70.75
# 8         1  a416b6a846a11724393025641d4edd5e  145.95          11.65
# 9         1  ba143b05f0110f0dc71ad71b4466ce92   53.99          11.40
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#                           seller_id   price  freight_value
# 0  3504c0cb71d7fa48d967e0e4c94d59d9   29.99           8.72
# 1  289cdb325fb7e7f891c38608bf9e0962  118.70          22.76
# 2  4869f7a5dfa277a7dca6462dcf3b52b2  159.90          19.22
# 3  66922902710d126a0e7d26b0e3805106   45.00          27.20
# 4  2c9e548be18521d1c43cde1c582c6de8   19.90           8.72
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#    ...   price  freight_value  product_category_name product_name_lenght  \
# 0  ...   29.99           8.72  utilidades_domesticas                40.0
# 1  ...  118.70          22.76             perfumaria                29.0
# 2  ...  159.90          19.22             automotivo                46.0
# 3  ...   45.00          27.20               pet_shop                59.0
# 4  ...   19.90           8.72              papelaria                38.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       178.0                 1.0             400.0
# 2                       232.0                 1.0             420.0
# 3                       468.0                 3.0             450.0
# 4                       316.0                 4.0             250.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               19.0                8.0              13.0
# 1               19.0               13.0              19.0
# 2               24.0               19.0              21.0
# 3               30.0               10.0              20.0
# 4               51.0               15.0              15.0
#
# [5 rows x 21 columns]
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#    ... freight_value  product_category_name  product_name_lenght  \
# 0  ...          8.72  utilidades_domesticas                 40.0
# 1  ...         22.76             perfumaria                 29.0
# 2  ...         19.22             automotivo                 46.0
# 3  ...         27.20               pet_shop                 59.0
# 4  ...          8.72              papelaria                 38.0
#
#   product_description_lenght  product_photos_qty  product_weight_g  \
# 0                      268.0                 4.0             500.0
# 1                      178.0                 1.0             400.0
# 2                      232.0                 1.0             420.0
# 3                      468.0                 3.0             450.0
# 4                      316.0                 4.0             250.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               19.0                8.0              13.0
# 1               19.0               13.0              19.0
# 2               24.0               19.0              21.0
# 3               30.0               10.0              20.0
# 4               51.0               15.0              15.0
#
#    product_category_name_english
# 0                     housewares
# 1                      perfumery
# 2                           auto
# 3                       pet_shop
# 4                     stationery
#
# [5 rows x 22 columns]
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#    ... product_description_lenght  product_photos_qty  product_weight_g  \
# 0  ...                      268.0                 4.0             500.0
# 1  ...                      178.0                 1.0             400.0
# 2  ...                      232.0                 1.0             420.0
# 3  ...                      468.0                 3.0             450.0
# 4  ...                      316.0                 4.0             250.0
#
#   product_length_cm  product_height_cm  product_width_cm  \
# 0              19.0                8.0              13.0
# 1              19.0               13.0              19.0
# 2              24.0               19.0              21.0
# 3              30.0               10.0              20.0
# 4              51.0               15.0              15.0
#
#    product_category_name_english  seller_zip_code_prefix      seller_city  \
# 0                     housewares                  9350.0             maua
# 1                      perfumery                 31570.0   belo horizonte
# 2                           auto                 14840.0          guariba
# 3                       pet_shop                 31842.0   belo horizonte
# 4                     stationery                  8752.0  mogi das cruzes
#
#    seller_state
# 0            SP
# 1            SP
# 2            SP
# 3            MG
# 4            SP
#
# [5 rows x 25 columns]
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#    ... product_height_cm  product_width_cm  product_category_name_english  \
# 0  ...               8.0              13.0                     housewares
# 1  ...              13.0              19.0                      perfumery
# 2  ...              19.0              21.0                           auto
# 3  ...              10.0              20.0                       pet_shop
# 4  ...              15.0              15.0                     stationery
#
#   seller_zip_code_prefix      seller_city  seller_state  \
# 0                 9350.0             maua            SP
# 1                31570.0   belo horizonte            SP
# 2                14840.0          guariba            SP
# 3                31842.0   belo horizonte            MG
# 4                 8752.0  mogi das cruzes            SP
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149
# 1  af07308b275d755c9edb36a90c618231                     47813
# 2  3a653a41f6f9fc3d2a113cf8398680e8                     75265
# 3  7c142cf63193a1473d2e66489a9ae977                     59296
# 4  72632f0f9dd73dfee390c9b22eb56dd6                      9195
#
#              customer_city  customer_state
# 0                sao paulo              SP
# 1                barreiras              BA
# 2               vianopolis              GO
# 3  sao goncalo do amarante              RN
# 4              santo andre              SP
#
# [5 rows x 29 columns]
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                        product_id  quantity  \
# 0           2017-10-18 00:00:00  87285b34884572647811a353c7ac498a       1.0
# 1           2018-08-13 00:00:00  595fac2a385ac33a80bd5114aec74eb8       1.0
# 2           2018-09-04 00:00:00  aa4383b373c6aca5d8797843e5594415       1.0
# 3           2017-12-15 00:00:00  d0b61bfb1de832b15ba9d266ca96e5b0       1.0
# 4           2018-02-26 00:00:00  65266b2da20d04dbe00c5c2d3bb7859e       1.0
#
#    ... product_category_name_english  seller_zip_code_prefix      seller_city  \
# 0  ...                    housewares                  9350.0             maua
# 1  ...                     perfumery                 31570.0   belo horizonte
# 2  ...                          auto                 14840.0          guariba
# 3  ...                      pet_shop                 31842.0   belo horizonte
# 4  ...                    stationery                  8752.0  mogi das cruzes
#
#   seller_state                customer_unique_id  customer_zip_code_prefix  \
# 0           SP  7c396fd4830fd04220f754e42b4e5bff                      3149
# 1           SP  af07308b275d755c9edb36a90c618231                     47813
# 2           SP  3a653a41f6f9fc3d2a113cf8398680e8                     75265
# 3           MG  7c142cf63193a1473d2e66489a9ae977                     59296
# 4           SP  72632f0f9dd73dfee390c9b22eb56dd6                      9195
#
#              customer_city  customer_state  overall_order_review_score  \
# 0                sao paulo              SP                         4.0
# 1                barreiras              BA                         4.0
# 2               vianopolis              GO                         5.0
# 3  sao goncalo do amarante              RN                         5.0
# 4              santo andre              SP                         5.0
#
#    overall_product_review_score
# 0                           4.0
# 1                           4.0
# 2                           5.0
# 3                           5.0
# 4                           5.0
#
# [5 rows x 31 columns]

# %%
# 3-2 Final Processing

# feature selection
orders_new.drop(axis = 1, columns = ["product_category_name", "product_name_lenght", "product_description_lenght", "product_photos_qty"], inplace = True)

# missing values
sns.heatmap(orders_new.isnull(), cbar = False) # heatmap
orders_new[orders_new["product_id"].isnull()] # these orders are all either cancelled or unavailable

# data consistency
orders_new["order_status"] = orders_new["order_status"].map({"unavailable":"unavailable", "delivered":"delivered", "canceled":"canceled", "shipped":"shipped", "created":"unprocessed", "invoiced":"unprocessed", "processing":"unprocessed", "approved": "unprocessed"}) # redefining order_status
# reorganisation of product categories was done in Tableau
# Out:
#                                 order_id                       customer_id  \
# 275     8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 605     c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 715     37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 771     d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1184    00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1215    2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# 1648    ee0db22a8e742b752914016708470ec8  aae50600d30bf2efe013ca4c1754ded7
# 1875    ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1902    6ad57aecbae806a7e9cc2cdb6b380711  d31dbd02ac052d662285f678f8994326
# 1946    df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2117    8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2240    9f3458f0433d4cfa472f4682654b8d49  99ebfafde8b9e58fd12db9d5cc83132f
# 2253    7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# 2391    f0df036e9be21fc238f131bbfcdde769  1fa16395beca89233661543954ca6cf1
# 2411    86f0bcd9b426a2c1022ae317c7f27be6  dd24965dd5aa551df36ce4baf180445b
# 2785    98fe01bc254b759c1f2c11d77c2891d5  30f3b26a06e5a67682305298f83e6be3
# 2813    f56dc9034c3962e36d49fb73baa12800  5c4795c07c0bd317adaf7406327bbfa9
# 3083    0130f0f71fb0e831d18e6a3b33a3a50c  e56f6dff7b8ac9813ddeb2312f0d834f
# 3172    ddaec6fff982b13e7e048b627a11d6da  68f4ad79cc0c2ad06e19088f5c00e9fa
# 3204    84b8ba39037606b7b30a39d02e9e4154  7c2bf05f6902368e5d21040b68c2bbdb
# 3214    5290c34bd38a8a095b885f13958db1e1  92af427e290117f39d9ff908566072e0
# 3589    2f30c0b1905c65a8ff6c6358bc909625  e963d0e4f815dcd28b135d7d340ec51a
# 3678    534a0fbe91a806a1dc6bf09b497e3d6f  d17ae8582d302dbd41b87e5028e8c0e2
# 3807    5965bbd72c3ca0d9634419437ca53897  3dd8536c33d454b9a9d05ba357eeaaa9
# 3820    03310aa823a66056268a3bab36e827fb  25dbbf0c477fd4ae0880aaffbb12e8b3
# 3924    b07abc8b9acaf00e79b4657419f469f3  15308b044c9608fc82e57f2e5d6878f6
# 4248    1ff6183537eb3a189de77b309ed28ad1  52ac1d5c2063338b5a45f69a14528c9b
# 4410    2411e5019928e883d049f7242362c23b  92ac70cce9e5ac1bb34996610d9564a4
# 4497    f8303e6eff198d1749d04649a1eb2bb6  4569e86ad4faba51cadc49ea1657ac3a
# 4539    4c8b9947280829d0a8b7e81cc249b875  403c35c4d8813bf67b3d396b91ca1619
# ...                                  ...                               ...
# 100074  bf3c691a76e2c8733340a8f7e251a0f1  dbc9104a798de0ff6af4de6a32c92f70
# 100230  02de1e44936e56ddc1621c46d86bf91e  c4c369211d1aaab90c8e097f6939dda2
# 100436  7159096c5aa9be77f7f0c26c01ee9793  d8f3aacf5cf5ddf9ceef4ad39e874c98
# 100650  5a14c8b3d919a4ef3f3428b0459c47b2  666094835d60d986eb87350b31efdcae
# 100756  b34369ee8397436dd7ceb8bb7783671d  c96771504b0c9d89ad8da161e0e3d092
# 100818  eb2dc067ee1a4eac77e2d045f01cf7f0  78101fe486eab484a8d65d53b69f4b09
# 101006  8298521946fcd8c9f8b984aad6176694  fc0f896db68de04d75532460d7c4b244
# 101136  11c71300049cd2c9896b0be33f04d574  12b6d8d5e5a754c23495e232fc4c2a86
# 101179  2e3c6e30c69763a7dfe40f11a19ed3da  9f33e47b96b9e034154df245350f37ee
# 101202  52fd8c890356febe4f78b653ef130cd2  21c57ebcb87ee3234cd00d36f40cfa9c
# 101332  efa3e0b795c3871ff5413d163cc9d6f0  d172c15ea2aca0b2d65e01a631df3d1a
# 101379  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 101629  73d6d096aaef87398a0321fc1acc5a54  444268cbb72dc57d82ba85089e29a93a
# 101676  af264f3527e94e431f0dcd56cd6b406d  8118922685d2e2c0205f060be4f2579c
# 101836  6c4e764954bc530adac8b0842d8f1647  dc480a485063e5b8e37bb77ed070514c
# 101883  37af1b25e7710f09d122aaf3f8b68114  f3b4b3f2136722924a0916a930b2081e
# 102135  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 102137  269507123b136cce3d2f6c5915f11bad  3bf75513c108eb186f5161d5b1dd8492
# 102214  abc371fa4448846ac98855c256ab235f  2ae960d0b2a92913f76520f59d0749b4
# 102348  1ce8144d59eef2763c0fbaf8ffd26d31  cffd70efba7f41e519157d935120f41b
# 102588  2d57932a94a64e0729ec5b88b4860d0d  18ee349e6fe0fa105ac44232ac1f4d06
# 102646  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 102798  e58b8168894c93cf61d36c90775acd85  65a227fbf7d798cdeadee8c0bea74993
# 102897  6cf5c427fb11bc5fe8abefa86aa7ba0b  91ac14a1e50bc022eeecf0c2ba37006a
# 102987  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 103007  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 103038  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 103104  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 103105  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 103173  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 275     unavailable      2017-11-16 15:09:28  2017-11-16 15:26:57
# 605     unavailable      2018-01-31 11:31:37  2018-01-31 14:23:50
# 715     unavailable      2017-08-14 17:38:02  2017-08-17 00:15:18
# 771     unavailable      2018-01-08 19:39:03  2018-01-09 07:26:08
# 1184       canceled      2018-08-28 15:26:39                  NaN
# 1215    unavailable      2017-09-27 20:55:33  2017-09-28 01:32:50
# 1648    unavailable      2017-08-24 11:04:41  2017-08-24 11:15:11
# 1875       canceled      2018-09-20 13:54:16                  NaN
# 1902    unavailable      2017-11-30 07:48:24  2017-11-30 08:14:42
# 1946       canceled      2017-03-04 12:14:30                  NaN
# 2117       canceled      2018-08-29 16:27:49                  NaN
# 2240    unavailable      2017-07-18 23:36:55  2017-07-18 23:50:17
# 2253       canceled      2017-05-01 16:12:39                  NaN
# 2391    unavailable      2017-02-24 23:39:21  2017-02-24 23:45:14
# 2411    unavailable      2017-03-08 15:13:03  2017-03-08 15:13:03
# 2785    unavailable      2017-10-17 18:34:56  2017-10-18 18:37:08
# 2813    unavailable      2017-08-10 22:20:51  2017-08-12 02:09:15
# 3083    unavailable      2017-05-12 10:17:23  2017-05-13 03:10:13
# 3172       canceled      2016-10-04 19:41:32                  NaN
# 3204    unavailable      2018-06-27 19:51:02  2018-06-27 20:11:41
# 3214       canceled      2018-08-21 10:25:18                  NaN
# 3589    unavailable      2017-12-08 09:32:48  2017-12-09 13:30:49
# 3678    unavailable      2018-01-22 02:45:40  2018-01-23 03:36:43
# 3807    unavailable      2017-01-30 10:29:25  2017-01-30 11:31:31
# 3820       canceled      2018-08-07 16:33:59                  NaN
# 3924    unavailable      2017-03-09 17:45:04  2017-03-09 17:45:04
# 4248    unavailable      2018-01-02 17:31:02  2018-01-04 11:57:21
# 4410    unavailable      2017-09-17 12:15:07  2017-09-17 12:25:09
# 4497    unavailable      2018-01-21 20:44:54  2018-01-22 13:58:50
# 4539       canceled      2018-08-09 14:54:47                  NaN
# ...             ...                      ...                  ...
# 100074  unavailable      2018-01-12 10:35:02  2018-01-16 04:31:05
# 100230  unavailable      2018-08-21 12:21:00  2018-08-21 12:35:12
# 100436     canceled      2018-03-15 10:06:35  2018-03-15 10:29:39
# 100650     canceled      2017-05-29 23:53:39                  NaN
# 100756     canceled      2017-06-07 20:11:29                  NaN
# 100818  unavailable      2017-12-04 23:16:03  2017-12-05 10:30:41
# 101006  unavailable      2017-03-07 23:02:58  2017-03-07 23:15:14
# 101136  unavailable      2017-06-15 10:07:14  2017-06-15 10:15:19
# 101179  unavailable      2017-10-23 18:24:27  2017-10-23 18:35:15
# 101202  unavailable      2017-02-08 13:03:36  2017-02-09 02:55:30
# 101332  unavailable      2017-11-17 19:42:32  2017-11-18 02:31:13
# 101379     canceled      2017-07-02 15:38:46                  NaN
# 101629  unavailable      2017-10-17 07:49:44  2017-10-17 08:07:12
# 101676  unavailable      2017-07-12 14:49:11  2017-07-12 15:04:10
# 101836  unavailable      2017-08-12 14:18:34  2017-08-12 18:35:16
# 101883  unavailable      2017-05-02 14:23:24  2017-05-02 14:31:40
# 102135     canceled      2017-09-28 15:02:56                  NaN
# 102137  unavailable      2018-02-12 21:13:25  2018-02-12 21:28:24
# 102214  unavailable      2017-02-11 19:26:28  2017-02-13 14:05:15
# 102348  unavailable      2017-08-10 12:44:08  2017-08-11 12:43:33
# 102588  unavailable      2018-03-31 19:08:47  2018-04-03 05:27:48
# 102646     canceled      2018-08-07 11:16:28                  NaN
# 102798  unavailable      2017-02-26 16:13:36  2017-02-26 16:25:15
# 102897  unavailable      2017-10-17 10:53:48  2017-10-19 03:12:43
# 102987  unavailable      2017-12-23 18:48:09  2017-12-23 18:54:22
# 103007  unavailable      2018-01-16 14:27:59  2018-01-17 03:37:34
# 103038     canceled      2018-08-31 16:13:44                  NaN
# 103104     canceled      2018-09-06 18:45:47                  NaN
# 103105  unavailable      2017-08-23 16:28:04  2017-08-28 15:44:47
# 103173  unavailable      2017-10-10 10:50:03  2017-10-14 18:35:57
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 275                             NaN                           NaN
# 605                             NaN                           NaN
# 715                             NaN                           NaN
# 771                             NaN                           NaN
# 1184                            NaN                           NaN
# 1215                            NaN                           NaN
# 1648                            NaN                           NaN
# 1875                            NaN                           NaN
# 1902                            NaN                           NaN
# 1946                            NaN                           NaN
# 2117                            NaN                           NaN
# 2240                            NaN                           NaN
# 2253                            NaN                           NaN
# 2391                            NaN                           NaN
# 2411                            NaN                           NaN
# 2785                            NaN                           NaN
# 2813                            NaN                           NaN
# 3083                            NaN                           NaN
# 3172                            NaN                           NaN
# 3204                            NaN                           NaN
# 3214                            NaN                           NaN
# 3589                            NaN                           NaN
# 3678                            NaN                           NaN
# 3807                            NaN                           NaN
# 3820                            NaN                           NaN
# 3924                            NaN                           NaN
# 4248                            NaN                           NaN
# 4410                            NaN                           NaN
# 4497                            NaN                           NaN
# 4539                            NaN                           NaN
# ...                             ...                           ...
# 100074                          NaN                           NaN
# 100230                          NaN                           NaN
# 100436                          NaN                           NaN
# 100650                          NaN                           NaN
# 100756                          NaN                           NaN
# 100818                          NaN                           NaN
# 101006                          NaN                           NaN
# 101136                          NaN                           NaN
# 101179                          NaN                           NaN
# 101202                          NaN                           NaN
# 101332                          NaN                           NaN
# 101379                          NaN                           NaN
# 101629                          NaN                           NaN
# 101676                          NaN                           NaN
# 101836                          NaN                           NaN
# 101883                          NaN                           NaN
# 102135                          NaN                           NaN
# 102137                          NaN                           NaN
# 102214                          NaN                           NaN
# 102348                          NaN                           NaN
# 102588                          NaN                           NaN
# 102646                          NaN                           NaN
# 102798                          NaN                           NaN
# 102897                          NaN                           NaN
# 102987                          NaN                           NaN
# 103007                          NaN                           NaN
# 103038                          NaN                           NaN
# 103104                          NaN                           NaN
# 103105                          NaN                           NaN
# 103173                          NaN                           NaN
#
#        order_estimated_delivery_date product_id  quantity  ...  \
# 275              2017-12-05 00:00:00        NaN       NaN  ...
# 605              2018-02-16 00:00:00        NaN       NaN  ...
# 715              2017-09-05 00:00:00        NaN       NaN  ...
# 771              2018-02-06 00:00:00        NaN       NaN  ...
# 1184             2018-09-12 00:00:00        NaN       NaN  ...
# 1215             2017-10-27 00:00:00        NaN       NaN  ...
# 1648             2017-09-18 00:00:00        NaN       NaN  ...
# 1875             2018-10-17 00:00:00        NaN       NaN  ...
# 1902             2017-12-29 00:00:00        NaN       NaN  ...
# 1946             2017-04-10 00:00:00        NaN       NaN  ...
# 2117             2018-09-13 00:00:00        NaN       NaN  ...
# 2240             2017-08-09 00:00:00        NaN       NaN  ...
# 2253             2017-05-30 00:00:00        NaN       NaN  ...
# 2391             2017-04-07 00:00:00        NaN       NaN  ...
# 2411             2017-03-29 00:00:00        NaN       NaN  ...
# 2785             2017-11-24 00:00:00        NaN       NaN  ...
# 2813             2017-09-14 00:00:00        NaN       NaN  ...
# 3083             2017-05-22 00:00:00        NaN       NaN  ...
# 3172             2016-11-16 00:00:00        NaN       NaN  ...
# 3204             2018-07-12 00:00:00        NaN       NaN  ...
# 3214             2018-09-06 00:00:00        NaN       NaN  ...
# 3589             2018-01-03 00:00:00        NaN       NaN  ...
# 3678             2018-02-06 00:00:00        NaN       NaN  ...
# 3807             2017-03-08 00:00:00        NaN       NaN  ...
# 3820             2018-09-04 00:00:00        NaN       NaN  ...
# 3924             2017-03-28 00:00:00        NaN       NaN  ...
# 4248             2018-01-31 00:00:00        NaN       NaN  ...
# 4410             2017-10-05 00:00:00        NaN       NaN  ...
# 4497             2018-02-21 00:00:00        NaN       NaN  ...
# 4539             2018-08-21 00:00:00        NaN       NaN  ...
# ...                              ...        ...       ...  ...
# 100074           2018-02-19 00:00:00        NaN       NaN  ...
# 100230           2018-08-29 00:00:00        NaN       NaN  ...
# 100436           2018-04-06 00:00:00        NaN       NaN  ...
# 100650           2017-06-23 00:00:00        NaN       NaN  ...
# 100756           2017-07-04 00:00:00        NaN       NaN  ...
# 100818           2017-12-20 00:00:00        NaN       NaN  ...
# 101006           2017-04-05 00:00:00        NaN       NaN  ...
# 101136           2017-06-29 00:00:00        NaN       NaN  ...
# 101179           2017-11-13 00:00:00        NaN       NaN  ...
# 101202           2017-03-07 00:00:00        NaN       NaN  ...
# 101332           2017-11-30 00:00:00        NaN       NaN  ...
# 101379           2017-07-25 00:00:00        NaN       NaN  ...
# 101629           2017-10-27 00:00:00        NaN       NaN  ...
# 101676           2017-08-11 00:00:00        NaN       NaN  ...
# 101836           2017-09-13 00:00:00        NaN       NaN  ...
# 101883           2017-05-29 00:00:00        NaN       NaN  ...
# 102135           2017-10-16 00:00:00        NaN       NaN  ...
# 102137           2018-03-13 00:00:00        NaN       NaN  ...
# 102214           2017-03-10 00:00:00        NaN       NaN  ...
# 102348           2017-09-01 00:00:00        NaN       NaN  ...
# 102588           2018-04-23 00:00:00        NaN       NaN  ...
# 102646           2018-08-10 00:00:00        NaN       NaN  ...
# 102798           2017-03-22 00:00:00        NaN       NaN  ...
# 102897           2017-10-27 00:00:00        NaN       NaN  ...
# 102987           2018-01-19 00:00:00        NaN       NaN  ...
# 103007           2018-02-06 00:00:00        NaN       NaN  ...
# 103038           2018-10-01 00:00:00        NaN       NaN  ...
# 103104           2018-09-27 00:00:00        NaN       NaN  ...
# 103105           2017-09-15 00:00:00        NaN       NaN  ...
# 103173           2017-10-23 00:00:00        NaN       NaN  ...
#
#        product_category_name_english  seller_zip_code_prefix  seller_city  \
# 275                              NaN                     NaN          NaN
# 605                              NaN                     NaN          NaN
# 715                              NaN                     NaN          NaN
# 771                              NaN                     NaN          NaN
# 1184                             NaN                     NaN          NaN
# 1215                             NaN                     NaN          NaN
# 1648                             NaN                     NaN          NaN
# 1875                             NaN                     NaN          NaN
# 1902                             NaN                     NaN          NaN
# 1946                             NaN                     NaN          NaN
# 2117                             NaN                     NaN          NaN
# 2240                             NaN                     NaN          NaN
# 2253                             NaN                     NaN          NaN
# 2391                             NaN                     NaN          NaN
# 2411                             NaN                     NaN          NaN
# 2785                             NaN                     NaN          NaN
# 2813                             NaN                     NaN          NaN
# 3083                             NaN                     NaN          NaN
# 3172                             NaN                     NaN          NaN
# 3204                             NaN                     NaN          NaN
# 3214                             NaN                     NaN          NaN
# 3589                             NaN                     NaN          NaN
# 3678                             NaN                     NaN          NaN
# 3807                             NaN                     NaN          NaN
# 3820                             NaN                     NaN          NaN
# 3924                             NaN                     NaN          NaN
# 4248                             NaN                     NaN          NaN
# 4410                             NaN                     NaN          NaN
# 4497                             NaN                     NaN          NaN
# 4539                             NaN                     NaN          NaN
# ...                              ...                     ...          ...
# 100074                           NaN                     NaN          NaN
# 100230                           NaN                     NaN          NaN
# 100436                           NaN                     NaN          NaN
# 100650                           NaN                     NaN          NaN
# 100756                           NaN                     NaN          NaN
# 100818                           NaN                     NaN          NaN
# 101006                           NaN                     NaN          NaN
# 101136                           NaN                     NaN          NaN
# 101179                           NaN                     NaN          NaN
# 101202                           NaN                     NaN          NaN
# 101332                           NaN                     NaN          NaN
# 101379                           NaN                     NaN          NaN
# 101629                           NaN                     NaN          NaN
# 101676                           NaN                     NaN          NaN
# 101836                           NaN                     NaN          NaN
# 101883                           NaN                     NaN          NaN
# 102135                           NaN                     NaN          NaN
# 102137                           NaN                     NaN          NaN
# 102214                           NaN                     NaN          NaN
# 102348                           NaN                     NaN          NaN
# 102588                           NaN                     NaN          NaN
# 102646                           NaN                     NaN          NaN
# 102798                           NaN                     NaN          NaN
# 102897                           NaN                     NaN          NaN
# 102987                           NaN                     NaN          NaN
# 103007                           NaN                     NaN          NaN
# 103038                           NaN                     NaN          NaN
# 103104                           NaN                     NaN          NaN
# 103105                           NaN                     NaN          NaN
# 103173                           NaN                     NaN          NaN
#
#         seller_state                customer_unique_id  \
# 275              NaN  41fc647b8c6bd979b1b6364b60471b50
# 605              NaN  0e634b16e4c585acbd7b2e8276ce6677
# 715              NaN  596ed6d7a35890b3fbac54ec01f69685
# 771              NaN  2349bbb558908e0955e98d47dacb7adb
# 1184             NaN  4fa4365000c7090fcb8cad5713c6d3db
# 1215             NaN  21c933c8dd97d088e64c50988c90ccf5
# 1648             NaN  bdc67efa33dd0c3228b91714ac6e363c
# 1875             NaN  08642cd329066fe11ec63293f714f2f8
# 1902             NaN  45b1948a7554a397cc42c2ea55c54ab6
# 1946             NaN  c219f4ac1bc7f1aea33e6ab8885831e8
# 2117             NaN  a8dd81392e5eee5d979c629a76abec2a
# 2240             NaN  a946faf63af327d1dd0362b3fa3882a3
# 2253             NaN  29dc4aeff866d6a940c471a3ea4faef0
# 2391             NaN  61181b9bc9188678b5991d89064dd961
# 2411             NaN  930c4390af58f67334447c3a1cf2ba36
# 2785             NaN  b9fdb2f344509f77f84250a748c6319c
# 2813             NaN  f3227a87d760e7bbcaf5377918fd68a5
# 3083             NaN  d4bf092ba54c293495ebbbd982d653d8
# 3172             NaN  00f0b70fdcb8a6e1671b52a2472bd41f
# 3204             NaN  36e06ca722231b14a75e6a33ffaa5f37
# 3214             NaN  e61f0f032bc92cadf0ec55f9c1c8b5ec
# 3589             NaN  215e0a9044344dca7820b462c60bd206
# 3678             NaN  cf41887f4cbf217c6fad258a83ba2d32
# 3807             NaN  b9efc86b7c6269eaeba5bdbdd5127e1b
# 3820             NaN  46450c74a0d8c5ca9395da1daac6c120
# 3924             NaN  fc44fbafeb777f4758880f91e2a33fe2
# 4248             NaN  93345700f0e852aa904fae18cec8437c
# 4410             NaN  af70cd6337ae27de089c616dad39bea0
# 4497             NaN  7b871ce95712547231108ebbbd4eceaf
# 4539             NaN  391d6062da3dd65b4de4524f28c478de
# ...              ...                               ...
# 100074           NaN  f361fb29d1b82df3c571339b1fd3735d
# 100230           NaN  24aa3d9034dd158d598b5fbb388f9bb3
# 100436           NaN  0858c8086ef3b4bc86fef82638bcfa52
# 100650           NaN  a128eb4a87a5195a3a5dfbdc3426c834
# 100756           NaN  04c55667b44fae5f50ed71d40c633d09
# 100818           NaN  337c366128e3c95a986ca2c89b7030d8
# 101006           NaN  5b67b2b422202d9bfd326ed53b7bd038
# 101136           NaN  7146a4a7f52aebbfe3a384100cd5c9d4
# 101179           NaN  9c783b71f0ea85aac770d6aa99e8a01d
# 101202           NaN  32300168b351a3fede32444fae9b7b25
# 101332           NaN  0d98133cd940dabf5ebe2742fb2fbc4a
# 101379           NaN  40d1c2a6b8ac6ccc102d473ff51cc46d
# 101629           NaN  a9b8b12b441cba8f5a0c1d70021f16d1
# 101676           NaN  d0e87d00021530383c16452a39a393ba
# 101836           NaN  b0e66140f2829b8be7786ba26cb1dc06
# 101883           NaN  05245bc04a232db14bfa07a935f8f0e2
# 102135           NaN  aa75afb965e89078d8681fe33aaaeded
# 102137           NaN  fcc8748e0d31248aea03fea7fce8da58
# 102214           NaN  70b1b3192204865d74286c5c85196102
# 102348           NaN  5195a43819843e980c42c5c1138b6a90
# 102588           NaN  78b9dd8b77ff3abe5f5b84bc2b030d1f
# 102646           NaN  13d7bd0b05e18b00f415221b3bb69348
# 102798           NaN  886c05aaa3a617c8b3a6b441eb88de2f
# 102897           NaN  9004096d8ffc515d4189e661fc4bcb84
# 102987           NaN  0aa3b096dc796c251f9b36a822051ed6
# 103007           NaN  a33e0969408919ba06779f497ead93ec
# 103038           NaN  e90598185d2427a35e32ef241a5c04aa
# 103104           NaN  d05c44a138277ad325d915c6b7ccbcdf
# 103105           NaN  e72a90a2b29fe1a8795b284aaaa3246f
# 103173           NaN  393d95c05b04db26ac084374094b3a52
#
#         customer_zip_code_prefix          customer_city customer_state  \
# 275                        89288       sao bento do sul             SC
# 605                        11701           praia grande             SP
# 715                         2318              sao paulo             SP
# 771                        48607           paulo afonso             BA
# 1184                        1151              sao paulo             SP
# 1215                        5017              sao paulo             SP
# 1648                       23027         rio de janeiro             RJ
# 1875                       33030            santa luzia             MG
# 1902                       18207           itapetininga             SP
# 1946                       68742              castanhal             PA
# 2117                       13059               campinas             SP
# 2240                       83328                pinhais             PR
# 2253                        5752              sao paulo             SP
# 2391                       76970          pimenta bueno             RO
# 2411                       87160             mandaguacu             PR
# 2785                       68553               redencao             PA
# 2813                       65075               sao luis             MA
# 3083                       13040               campinas             SP
# 3172                        5362              sao paulo             SP
# 3204                        1522              sao paulo             SP
# 3214                       13848             mogi-guacu             SP
# 3589                       14010         ribeirao preto             SP
# 3678                        5877              sao paulo             SP
# 3807                       37701        pocos de caldas             MG
# 3820                       88034          florianopolis             SC
# 3924                        2307              sao paulo             SP
# 4248                       26087            nova iguacu             RJ
# 4410                       35450              itabirito             MG
# 4497                       89874              maravilha             SC
# 4539                        3461              sao paulo             SP
# ...                          ...                    ...            ...
# 100074                     35400             ouro preto             MG
# 100230                      2363              sao paulo             SP
# 100436                     79118           campo grande             MS
# 100650                     89225              joinville             SC
# 100756                     12092                taubate             SP
# 100818                      8790        mogi das cruzes             SP
# 101006                     65460              pirapemas             MA
# 101136                      4304              sao paulo             SP
# 101179                     27274          volta redonda             RJ
# 101202                      2188              sao paulo             SP
# 101332                      3922              sao paulo             SP
# 101379                     29156              cariacica             ES
# 101629                      7251              guarulhos             SP
# 101676                     45810           porto seguro             BA
# 101836                     24461            sao goncalo             RJ
# 101883                     79113           campo grande             MS
# 102135                     12940                atibaia             SP
# 102137                     81310               curitiba             PR
# 102214                     28605          nova friburgo             RJ
# 102348                      6774        taboao da serra             SP
# 102588                     11630               ilhabela             SP
# 102646                      9810  sao bernardo do campo             SP
# 102798                     83325                pinhais             PR
# 102897                      3759              sao paulo             SP
# 102987                     14750           pitangueiras             SP
# 103007                      7025              guarulhos             SP
# 103038                     11075                 santos             SP
# 103104                      5344              sao paulo             SP
# 103105                     22723         rio de janeiro             RJ
# 103173                     18040               sorocaba             SP
#
#         overall_order_review_score overall_product_review_score
# 275                            1.0                          NaN
# 605                            3.0                          NaN
# 715                            1.0                          NaN
# 771                            1.0                          NaN
# 1184                           1.0                          NaN
# 1215                           1.0                          NaN
# 1648                           1.0                          NaN
# 1875                           2.0                          NaN
# 1902                           1.0                          NaN
# 1946                           3.0                          NaN
# 2117                           5.0                          NaN
# 2240                           5.0                          NaN
# 2253                           5.0                          NaN
# 2391                           1.0                          NaN
# 2411                           4.0                          NaN
# 2785                           1.0                          NaN
# 2813                           3.0                          NaN
# 3083                           1.0                          NaN
# 3172                           1.0                          NaN
# 3204                           1.0                          NaN
# 3214                           3.0                          NaN
# 3589                           NaN                          NaN
# 3678                           1.0                          NaN
# 3807                           1.0                          NaN
# 3820                           1.0                          NaN
# 3924                           1.0                          NaN
# 4248                           1.0                          NaN
# 4410                           1.0                          NaN
# 4497                           1.0                          NaN
# 4539                           1.0                          NaN
# ...                            ...                          ...
# 100074                         1.0                          NaN
# 100230                         3.0                          NaN
# 100436                         1.0                          NaN
# 100650                         5.0                          NaN
# 100756                         5.0                          NaN
# 100818                         4.0                          NaN
# 101006                         4.0                          NaN
# 101136                         1.0                          NaN
# 101179                         1.0                          NaN
# 101202                         1.0                          NaN
# 101332                         1.0                          NaN
# 101379                         1.0                          NaN
# 101629                         1.0                          NaN
# 101676                         5.0                          NaN
# 101836                         5.0                          NaN
# 101883                         1.0                          NaN
# 102135                         1.0                          NaN
# 102137                         1.0                          NaN
# 102214                         1.0                          NaN
# 102348                         2.0                          NaN
# 102588                         5.0                          NaN
# 102646                         2.0                          NaN
# 102798                         1.0                          NaN
# 102897                         1.0                          NaN
# 102987                         1.0                          NaN
# 103007                         1.0                          NaN
# 103038                         5.0                          NaN
# 103104                         4.0                          NaN
# 103105                         1.0                          NaN
# 103173                         1.0                          NaN
#
# [775 rows x 27 columns]

# %%
# 4-2 The First Question

# QRR
quarter = pd.to_datetime(orders_new["order_purchase_timestamp"]).dt.to_period("Q")
cuid = orders_new["customer_unique_id"]

def purchased_last_quarter(x):    
    cond = (quarter == x[1]) & (cuid == x[0])
    return cond.any()

last_quarter = quarter - 1
helper = (cuid + " " + last_quarter.astype(str)).str.split(" ")
orders_new["purchased_last_quarter"] = helper.apply(purchased_last_quarter)

orders_new["quarter"] = quarter
numerator = orders_new[orders_new["purchased_last_quarter"] == 1].groupby("quarter")["customer_unique_id"].nunique()
denominator = orders_new.groupby("quarter")["customer_unique_id"].nunique()
numerator / denominator.shift(1) # QRR for each applicable fiscal quarter
# Out:
# quarter
# 2016Q3         NaN
# 2016Q4         NaN
# 2017Q1    0.003106
# 2017Q2    0.009897
# 2017Q3    0.010723
# 2017Q4    0.010944
# 2018Q1    0.007998
# 2018Q2    0.009534
# 2018Q3    0.005377
# 2018Q4    0.000158
# Freq: Q-DEC, Name: customer_unique_id, dtype: float64
